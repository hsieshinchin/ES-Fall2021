# %%
print('hello AI. I am TA Grace. Nice to meet you')
# Out:
# hello AI. I am TA Grace. Nice to meet you

# %%
print('Today is Sunday,2021.11.07')
# Out:
# Today is Sunday,2021.11.07

# %% [markdown]
# # I am TA Grace
# ## I am TA Grace
# ### I am TA Grace
# * Grace 1
# * Grace 2
# * Grace 3
